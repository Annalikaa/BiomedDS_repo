# %% [markdown]
# <a href="https://colab.research.google.com/github/Annalikaa/BiomedDS_repo/blob/main/notebook1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
4 + 4

# %% [markdown]
# this is a text chunk
